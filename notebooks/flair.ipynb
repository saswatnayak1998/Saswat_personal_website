# %%
from flair.models import TextClassifier
from flair.data import Sentence
sia = TextClassifier.load('en-sentiment')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from flair.models import TextClassifier
#       2 from flair.data import Sentence
#       3 sia = TextClassifier.load('en-sentiment')
#
# File ~/Documents/Saswat_personal_website/venvv/lib/python3.9/site-packages/flair/__init__.py:42
#      39 # global variable: arrow symbol
#      40 _arrow = " → "
# ---> 42 from . import (  # noqa: E402 import after setting device
#      43     data,
#      44     models,
#      45     nn,
#      46     trainers,
#      47     visual,
#      48 )
#      50 logging.config.dictConfig(
#      51     {
#      52         "version": 1,
#    (...)
#      64     }
#      65 )
#      67 logger = logging.getLogger("flair")
#
# File ~/Documents/Saswat_personal_website/venvv/lib/python3.9/site-packages/flair/models/__init__.py:1
# ----> 1 from .clustering import ClusteringModel
# ...

# %%
x = "Google announced new pixel phones"
sentence = Sentence(x)
sia.predict(sentence)
score = sentence.labels[0]

# %%
# !pip3 install scipy
